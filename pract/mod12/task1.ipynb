# %%
import sqlite3
import pandas as pd

# %%
conn_netflix = sqlite3.connect('netflix.sqlite')
df = pd.read_sql("SELECT * FROM netflix_titles", conn_netflix)

# %%
actors = []
actor_title = pd.DataFrame(columns = ['show_id', 'actor_id'])
i = 0
for index, row in df.iterrows():
    cast = row['cast'].split(', ')
    show_id = row['show_id']
    for actor in cast:
      if actor not in actors: actors.append(actor)
      actor_id = actors.index(actor)
      actor_title.loc[i] = [show_id, actor_id]
      i += 1
actor_title.head(5)
# Out:
#     show_id  actor_id
# 0  81145628         0
# 1  81145628         1
# 2  81145628         2
# 3  81145628         3
# 4  81145628         4

# %%
df_actors = pd.DataFrame(actors)
df.pop('cast')
df.head(5)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director                                   country  \
# 0  Richard Finn, Tim Maltby  United States, India, South Korea, China
# 1                                                      United Kingdom
# 2                                                       United States
# 3                                                       United States
# 4          Fernando Lebrija                             United States
#
#           date_added  release_year    rating  duration  \
# 0  September 9, 2019          2019     TV-PG    90 min
# 1  September 9, 2016          2016     TV-MA    94 min
# ...

# %%
conn = sqlite3.connect('task1.sqlite')
df.to_sql('movies', conn)
df_actors.to_sql('actors', conn)
df_actor_title.to_sql('actor_to_movie', conn)
# Out:
# 44881

# %%
df_test = pd.read_sql('''SELECT a1.[0] AS first_actor, a2.[0] AS second_actor,
  COUNT(*) AS count_worked
  FROM actor_to_movie at1
  JOIN actor_to_movie at2 ON at1.show_id = at2.show_id AND at1.actor_id < at2.actor_id
  JOIN actors a1 ON at1.actor_id = a1.[index]
  JOIN actors a2 ON at2.actor_id = a2.[index]
  GROUP BY a1.[0], a2.[0]
  ORDER BY count_worked DESC
  LIMIT 5;''', conn)
print(df_test)
# Out:
#           first_actor   second_actor  count_worked
# 0  John Paul Tremblay     Robb Wells            15
# 1           Eric Idle    John Cleese            14
# 2           Eric Idle  Michael Palin            14
# 3           Eric Idle    Terry Jones            14
# 4         John Cleese  Michael Palin            14
